# %%
import pandas as pd

ruta_archivo1= '/Users/luciaprietogonzalez/Documents/Universidad/CURSO4/TFG/TFG DEFINITIVO/DESARROLLO/TFG/Tablas originales/MentalHealthAños/Mental_Health_Tech_Survey_2014.csv'  
ruta_archivo2= '/Users/luciaprietogonzalez/Documents/Universidad/CURSO4/TFG/TFG DEFINITIVO/DESARROLLO/TFG/Tablas originales/MentalHealthAños/Mental_Health_Tech_Survey_2016.csv' 
ruta_archivo3= '/Users/luciaprietogonzalez/Documents/Universidad/CURSO4/TFG/TFG DEFINITIVO/DESARROLLO/TFG/Tablas originales/MentalHealthAños/Mental_Health_Tech_Survey_2017.csv' 
ruta_archivo4= '/Users/luciaprietogonzalez/Documents/Universidad/CURSO4/TFG/TFG DEFINITIVO/DESARROLLO/TFG/Tablas originales/MentalHealthAños/Mental_Health_Tech_Survey_2018.csv' 
ruta_archivo5= '/Users/luciaprietogonzalez/Documents/Universidad/CURSO4/TFG/TFG DEFINITIVO/DESARROLLO/TFG/Tablas originales/MentalHealthAños/Mental_Health_Tech_Survey_2019.csv' 
ruta_archivo6= '/Users/luciaprietogonzalez/Documents/Universidad/CURSO4/TFG/TFG DEFINITIVO/DESARROLLO/TFG/Tablas originales/MentalHealthAños/Mental_Health_Tech_Survey_2020.csv'

#importar el archivo csv y crear el DataFrame
datos_tech_2014 = pd.read_csv(ruta_archivo1)
datos_tech_2016 = pd.read_csv(ruta_archivo2)
datos_tech_2017 = pd.read_csv(ruta_archivo3)
datos_tech_2018 = pd.read_csv(ruta_archivo4)
datos_tech_2019 = pd.read_csv(ruta_archivo5)
datos_tech_2020 = pd.read_csv(ruta_archivo6)

# %%
print("2014")
print(datos_tech_2014.dtypes)

print("\n2016")
print(datos_tech_2016.dtypes)

print("\n2017")
print(datos_tech_2017.dtypes)

print("\n2018")
print(datos_tech_2018.dtypes)

print("\n2019")
print(datos_tech_2019.dtypes)

print("\n2020")
print(datos_tech_2020.dtypes)
# Out:
# 2014
# Timestamp                                                                                                               object
# Age                                                                                                                      int64
# Gender                                                                                                                  object
# Country                                                                                                                 object
# If you live in the United States, which state or territory do you live in?                                              object
# Are you self-employed?                                                                                                  object
# Do you have a family history of mental illness?                                                                         object
# ...
